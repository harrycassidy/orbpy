# %%
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

def evolve(self):           # evolve the trajectories
        dt = 1.0
        plots = []
        lines = []
        for p in self.planets:
            p.r += p.v * dt
            acc = -2.959e-4 * p.r / np.sum(p.r**2)**(3./2)  # in units of AU/day^2
            p.v += acc * dt
            p.xs.append(p.r[0])
            p.ys.append(p.r[1])
            p.plot.set_offsets(p.r[:2])
            p.line.set_xdata(p.xs)
            p.line.set_ydata(p.ys)
            plots.append(p.plot)
            lines.append(p.line)
       
        return plots + lines 
def animate(i):
    return evolve()
ani = animation.FuncAnimation(fig, animate, repeat=False, frames=sim_duration, blit=True, interval=20,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\as330\lib\site-packages\astropy\time\core.py in _get_time_fmt(self, val, val2, format, scale, precision, in_subfmt, out_subfmt)
#     438             try:
# --> 439                 return cls(val, val2, scale, precision, in_subfmt, out_subfmt)
#     440             except UnitConversionError:
#
# ~\Anaconda3\envs\as330\lib\site-packages\astropy\time\formats.py in __init__(self, val1, val2, scale, precision, in_subfmt, out_subfmt, from_jd)
#     140         self.in_subfmt = in_subfmt
# --> 141         self.out_subfmt = out_subfmt
#     142
#
# ~\Anaconda3\envs\as330\lib\site-packages\astropy\time\formats.py in out_subfmt(self, subfmt)
#     182         # Validate subfmt value for this class, raises ValueError if not.
# --> 183         self._select_subfmts(subfmt)
#     184         self._out_subfmt = subfmt
#
# ~\Anaconda3\envs\as330\lib\site-packages\astropy\time\formats.py in _select_subfmts(cls, pattern)
#     398                 subfmt_names = [x[0] for x in cls.subfmts]
# --> 399                 raise ValueError(f'subformat {pattern!r} must match one of '
#     400                                  f'{subfmt_names} for format {cls.name}')
#
# ValueError: subformat 'date' must match one of ['float', 'long', 'decimal', 'str', 'bytes'] for format jd
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-91fd8f311591> in <module>
#       5 def animate(i):
#       6     return ss.evolve()
# ----> 7 ani = animation.FuncAnimation(fig, animate, repeat=False, frames=sim_duration, blit=True, interval=20,)
#       8 plt.show()
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1703         self._save_seq = []
#    1704
# -> 1705         super().__init__(fig, **kwargs)
#    1706
#    1707         # Need to reset the saved seq, since right now it will contain data
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1465         if event_source is None:
#    1466             event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1467         super().__init__(fig, event_source=event_source, *args, **kwargs)
#    1468
#    1469     def _step(self, *args):
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py in __init__(self, fig, event_source, blit)
#     967                                                       self._stop)
#     968         if self._blit:
# --> 969             self._setup_blit()
#     970
#     971     def __del__(self):
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py in _setup_blit(self)
#    1279         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1280                                                        self._on_resize)
# -> 1281         self._post_draw(None, self._blit)
#    1282
#    1283     def _on_resize(self, event):
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py in _post_draw(self, framedata, blit)
#    1232             self._blit_draw(self._drawn_artists)
#    1233         else:
# -> 1234             self._fig.canvas.draw_idle()
#    1235
#    1236     # The rest of the code in this class is to facilitate easy blitting
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def get_width_height(self):
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2798             self.stale = False
#    2799
# -> 2800         self.canvas.draw_event(renderer)
#    2801
#    2802     def draw_artist(self, a):
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\backend_bases.py in draw_event(self, renderer)
#    1790         s = 'draw_event'
#    1791         event = DrawEvent(s, self, renderer)
# -> 1792         self.callbacks.process(s, event)
#    1793
#    1794     def resize_event(self):
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\cbook\__init__.py in process(self, s, *args, **kwargs)
#     273                 except Exception as exc:
#     274                     if self.exception_handler is not None:
# --> 275                         self.exception_handler(exc)
#     276                     else:
#     277                         raise
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\cbook\__init__.py in _exception_printer(exc)
#      87 def _exception_printer(exc):
#      88     if _get_running_interactive_framework() in ["headless", None]:
# ---> 89         raise exc
#      90     else:
#      91         traceback.print_exc()
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\cbook\__init__.py in process(self, s, *args, **kwargs)
#     268             if func is not None:
#     269                 try:
# --> 270                     func(*args, **kwargs)
#     271                 # this does not capture KeyboardInterrupt, SystemExit,
#     272                 # and GeneratorExit
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py in _start(self, *args)
#     989
#     990         # Now do any initial draw
# --> 991         self._init_draw()
#     992
#     993         # Add our callback for stepping the animation and
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py in _init_draw(self)
#    1751         # artists.
#    1752         if self._init_func is None:
# -> 1753             self._draw_frame(next(self.new_frame_seq()))
#    1754
#    1755         else:
#
# ~\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py in _draw_frame(self, framedata)
#    1774         # Call the func with framedata and args. If blitting is desired,
#    1775         # func needs to return a sequence of any artists that were modified.
# -> 1776         self._drawn_artists = self._func(framedata, *self._args)
#    1777
#    1778         if self._blit:
#
# <ipython-input-4-91fd8f311591> in animate(i)
#       4
#       5 def animate(i):
# ----> 6     return ss.evolve()
#       7 ani = animation.FuncAnimation(fig, animate, repeat=False, frames=sim_duration, blit=True, interval=20,)
#       8 plt.show()
#
# <ipython-input-3-c9b0d348a590> in evolve(self)
#      44             plots.append(p.plot)
#      45             lines.append(p.line)
# ---> 46         self.timestamp.set_text('Date: ' + Time(self.time, format='jd', out_subfmt='date').iso)
#      47         return plots + lines + [self.timestamp]
#      48
#
# ~\Anaconda3\envs\as330\lib\site-packages\astropy\time\core.py in __init__(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, location, copy)
#    1525                 self._set_scale(scale)
#    1526         else:
# -> 1527             self._init_from_vals(val, val2, format, scale, copy,
#    1528                                  precision, in_subfmt, out_subfmt)
#    1529             self.SCALES = TIME_TYPES[self.scale]
#
# ~\Anaconda3\envs\as330\lib\site-packages\astropy\time\core.py in _init_from_vals(self, val, val2, format, scale, copy, precision, in_subfmt, out_subfmt)
#     379
#     380         # Parse / convert input values into internal jd1, jd2 based on format
# --> 381         self._time = self._get_time_fmt(val, val2, format, scale,
#     382                                         precision, in_subfmt, out_subfmt)
#     383         self._format = self._time.name
#
# ~\Anaconda3\envs\as330\lib\site-packages\astropy\time\core.py in _get_time_fmt(self, val, val2, format, scale, precision, in_subfmt, out_subfmt)
#     445                 # easier for user to see what is wrong.
#     446                 if len(formats) == 1:
# --> 447                     raise ValueError(
#     448                         f'Input values did not match the format class {format}:'
#     449                         + os.linesep
#
# ValueError: Input values did not match the format class jd:
# ValueError: subformat 'date' must match one of ['float', 'long', 'decimal', 'str', 'bytes'] for format jd

# %%
#Juppiter testing

# %%
import math
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

#style choices
plt.rcParams["figure.figsize"] = [16.4, 10.8]


def _update_plot(i, fig, scat):
    scat.set_offsets(([i, ((i**2)-(11*i)+400)], [50, i]))
    #print('Frames: %d' %i)

    return scat





fig = plt.figure()

x = [1]
y = [1]

ax = fig.add_subplot(111)
ax.grid(True, linestyle = '-', color = '0.50')
ax.set_xlim([-400, 800])
ax.set_ylim([-400, 800])

scat = plt.scatter(x, y, c = x)
scat.set_alpha(0.5)

anim = animation.FuncAnimation(fig, _update_plot, fargs = (fig, scat),
                                frames = 200, interval = 300)

plt.show()
# Out:
# C:\Users\harry\Anaconda3\envs\as330\lib\site-packages\matplotlib\animation.py:973: UserWarning: Animation was deleted without rendering anything. This is most likely unintended. To prevent deletion, assign the Animation to a variable that exists for as long as you need the Animation.
#   warnings.warn(
